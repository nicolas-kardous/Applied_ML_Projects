# %% [markdown]
# # Lab 3 - Instrumental variable
# - **Author:** Dimitris Papadimitriou ([dimitri@berkeley.edu](mailto:dimitri@berkeley.edu))
# - **Date:** 12 February 2020
# - **Course:** INFO 251: Applied machine learning

# %% [markdown]
# ### Learning Objectives:
# By the end of the lab, you will be able to:
#
# * work with real dataset to analyze instrumental variable

# %% [markdown]
# ### Topics:
# 1. Instrumental variable

# %% [markdown]
# ### References:
#  * [Instrumental Variables Estimation](https://github.com/natematias/research_in_python/blob/master/instrumental_variables_estimation/Instrumental-Variables%20Estimation.ipynb) by NATHAN MATIAS
#  * [What is education’s impact on civic and social engagement?](http://www.oecd.org/edu/innovation-education/37425694.pdf) by David Campbell
#  * Ecnometric Analysis, W. Greene, chapter 5.4

# %% [markdown]
# ### Refresh (from slides)

# %% [markdown]
# Instrumental Variables (“two stage least squares”) is a two-step procedure for estimating X’s effect on Y

# %% [markdown]
# * You want to estimate: $𝑌_𝑖 = \alpha + \beta𝑋_𝑖+ 𝑢_𝑖$
# * Suppose that you have a valid instrument $Z_i$
# * Stage 1: $X_i = b_0 + b_1 Z_𝑖 + 𝜈_𝑖$
#     * Obtain predicted values $\hat{𝑋_𝑖}$
# * Stage 2: $Y_i = \alpha + \beta \hat{𝑋_𝑖} + 𝑢_𝑖$

# %% [markdown]
# Recall that for an instrumental variable Z to be valid it must satisfy two conditions:
# * Instrument relevance: $corr(Z_i,X_𝑖)\ne 0$
# * Instrument exogeneity: $corr(Z_i, u_𝑖) = 0$

# %% [markdown]
# ## Example: Does college attainment lead to more income?

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /Applications/anaconda/envs/py3k/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
college_distance = pd.read_csv('CollegeDistance.csv')
college_distance.head()
# Out:
#    id  gender ethnicity      score fcollege mcollege home urban  unemp  wage  \
# 0   1    male     other  39.150002      yes       no  yes   yes    6.2  8.09
# 1   2  female     other  48.869999       no       no  yes   yes    6.2  8.09
# 2   3    male     other  48.740002       no       no  yes   yes    6.2  8.09
# 3   4    male      afam  40.400002       no       no  yes   yes    6.2  8.09
# 4   5  female     other  40.480000       no       no   no   yes    5.6  8.09
#
#    distance  tuition  education income region
# 0       0.2  0.88915         12   high  other
# 1       0.2  0.88915         12    low  other
# 2       0.2  0.88915         12    low  other
# 3       0.2  0.88915         12    low  other
# 4       0.4  0.88915         13    low  other

# %%
college_distance.shape
# Out:
# (4739, 15)

# %%
college_distance[['wage', 'education', 'distance']].describe()
# Out:
#               wage    education     distance
# count  4739.000000  4739.000000  4739.000000
# mean      9.500506    13.807765     1.802870
# std       1.343067     1.789107     2.297128
# min       6.590000    12.000000     0.000000
# 25%       8.850000    12.000000     0.400000
# 50%       9.680000    13.000000     1.000000
# 75%      10.150000    16.000000     2.500000
# max      12.960000    18.000000    20.000000

# %%
college_distance[['wage', 'education', 'distance']].corr()
# Out:
#                wage  education  distance
# wage       1.000000   0.023858 -0.000390
# education  0.023858   1.000000 -0.093183
# distance  -0.000390  -0.093183  1.000000

# %%
result = smf.ols(formula = "wage ~ education", data = college_distance).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.698
# Date:                Wed, 12 Sep 2018   Prob (F-statistic):              0.101
# Time:                        11:19:36   Log-Likelihood:                -8120.3
# No. Observations:                4739   AIC:                         1.624e+04
# Df Residuals:                    4737   BIC:                         1.626e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.2532      0.152     60.949      0.000       8.956       9.551
# education      0.0179      0.011      1.643      0.101      -0.003       0.039
# ==============================================================================
# Omnibus:                       24.254   Durbin-Watson:                   0.117
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.292
# Skew:                           0.094   Prob(JB):                     3.92e-05
# Kurtosis:                       2.741   Cond. No.                         109.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Exercise: implement instrumental variable estimation
